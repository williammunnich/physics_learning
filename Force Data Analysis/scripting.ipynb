# %%
import pandas as pd
import tkinter as tk
from tkinter import filedialog
from io import StringIO
import csv
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Open a file dialog to select a CSV file
file_path = filedialog.askopenfilename()

if file_path:
    print("Selected file:", file_path)
else:
    print("No file selected.")

# Function to read data from CSV file
def read_csv(file_path1):
    data = []
    with open(file_path1, 'r') as csvfile:
        csvreader = csv.reader(csvfile)
        for row in csvreader:
            data.append(row)
    return data

# Function to plot the graph
def plot_graph(data):
    x_values = []
    y_values = []
    for row in data[2:]:
        x_values.append(float(row[0]))
        y_values.append(float(row[1]))

    plt.plot(x_values, y_values)
    plt.xlabel('Sequence')
    plt.ylabel('Volt')
    plt.title('Impulse Force Measures')
    plt.grid(True)
    plt.show()

# Main function
def main():
    # Change this to your CSV file path
    data = read_csv(file_path)
    plot_graph(data)

main()
# Out:
# Selected file: C:/Users/kg7481ty/Documents/GitHub/physics_learning/laser_day1/2024-03-08 F(t) Al target 1/Newfile1.csv
